# %%
#import all useful libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import our data
data = pd.read_csv('penguins.csv')

# %%
print(data.head())
data_clean = data.dropna()
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
#prjec
att = data_clean.iloc[:,3:5]
print(att.head())
# Out:
#    bill_length_mm  bill_depth_mm
# 0            39.1           18.7
# 1            39.5           17.4
# 2            40.3           18.0
# 4            36.7           19.3
# 5            39.3           20.6

# %%
line=np.array([1.3,2.5])
unit_line=line/np.linalg.norm(line,2)
proj=np.dot(att,unit_line)[:,np.newaxis]*unit_line

#plot
plt.scatter(att.iloc[:,0],att.iloc[:,1])
plt.scatter(proj[:,0],proj[:,1],color= 'red')

# %%
#Find mean of the data
centroid =df.mean()
print(centroid)
# Out:
# bill_length_mm    43.992793
# bill_depth_mm     17.164865
# dtype: float64

# %%
#center your data
df_center=df-centroid 
plt.scatter(df_center.iloc[:,0],df_center.iloc[:,1])
plt.grid()

# %%
#print(data_clean['variety'].unique)
print(data_clean.head())
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
# 5      6  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 4       3450.0  female  2007
# 5       3650.0    male  2007

# %%
# Choose subset of your attributes:

# df=data_clean.iloc[:,:2]
#or
# df=data_clean[['bill_length_mm','bill_depth_mm']]

# %%
# Out:
# bill_length_mm    43.992793
# bill_depth_mm     17.164865
# dtype: float64

# %%
#plt.scatter(df.iloc[:,0], df.iloc[:,1])
#plt.grid()
#plt.xlabel('bill_length_mm')
#plt.scatter(centroid[0],centroid[1],c='red')

# %%
#line=np.array([-2.15, 2.75])
#line_unit= line/np.linalg.norm(line,2)

# %%
#project points to line (dot product)
#proj=np.dot(centroid,line_unit)*line_unit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #project points to line (dot product)
# ----> 2 proj=np.dot(centroidr,line_unit)*line_unit
#
# NameError: name 'centroidr' is not defined

# %%
#datapro=np.dot(df_center, line_unit)[:,np.newaxis]*line_unit

# %%
#plt.scatter(datapro[:,0], datapro[:,1])
#plt.scatter(df_center.iloc[:,0], df_center.iloc[:,1], c='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.scatter(datapro[:,0], datapro[:,1])
#       2 plt.scatter(df_center.iloc[:,0], df_center.iloc[:,1], c='red')
#
# NameError: name 'datapro' is not defined
